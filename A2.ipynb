# %% [markdown]
# # ASSIGNMENT 2 - DATA PROCESSING

# %% [markdown]
# # Phase 0 - Project set up

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Phase 1 – Data Loading and Initial Inspection

# %% [markdown]
# ## 1.1 Load dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("bs140513_032310.csv")

# %% [markdown]
# ## 1.2 Inspect structure

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594643 entries, 0 to 594642
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   step         594643 non-null  int64
#  1   customer     594643 non-null  object
#  2   age          594643 non-null  object
#  3   gender       594643 non-null  object
#  4   zipcodeOri   594643 non-null  object
#  5   merchant     594643 non-null  object
#  6   zipMerchant  594643 non-null  object
#  7   category     594643 non-null  object
#  8   amount       594643 non-null  float64
#  9   fraud        594643 non-null  int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 45.4+ MB
#                 step         amount          fraud
# count  594643.000000  594643.000000  594643.000000
# mean       94.986827      37.890135       0.012108
# std        51.053632     111.402831       0.109369
# min         0.000000       0.000000       0.000000
# 25%        52.000000      13.740000       0.000000
# 50%        97.000000      26.900000       0.000000
# 75%       139.000000      42.540000       0.000000
# max       179.000000    8329.960000       1.000000

# %% [markdown]
# # Phase2 - Basic Cleaning

# %% [markdown]
# ## 2.1 Remove duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## 2.2 Handle missing values

# %%
df['amount'] = df['amount'].fillna(df['amount'].median())

df['merchant'] = df['merchant'].fillna(df['merchant'].mode()[0])
df['category'] = df['category'].fillna(df['category'].mode()[0])

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['step', 'customer', 'age', 'gender', 'zipcodeOri', 'merchant',
#        'zipMerchant', 'category', 'amount', 'fraud'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# step           0
# customer       0
# age            0
# gender         0
# zipcodeOri     0
# merchant       0
# zipMerchant    0
# category       0
# amount         0
# fraud          0
# dtype: int64

# %% [markdown]
# ## 2.3 Remove invalid values

# %%
df['fraud'] = df['fraud'].astype(int)

# %% [markdown]
# # PHASE 3 - Data Type Correction & Sorting (CRITICAL)

# %% [markdown]
# ## 3.1 Data Type Correction

# %%
df['fraud'] = df['fraud'].astype(int)
df['step'] = df['step'].astype(int)
df['amount'] = df['amount'].astype(float)

# %% [markdown]
# ## 3.2 Sort by customer + time

# %%
df = df.sort_values(['customer', 'step']).copy()

# %% [markdown]
# ## 3.3 Reset index

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 3.4 Testing the logic

# %%
df[df['customer'] == df['customer'].iloc[0]][['step', 'amount']].head(10)
# Out:
#    step  amount
# 0    30  143.87
# 1    38   16.69
# 2    42   56.18
# 3    43   14.74
# 4    44   47.42
# 5    45    1.71
# 6    46   34.79
# 7    47   55.14
# 8    48   14.84
# 9    49   13.23

# %% [markdown]
# # PHASE 4 - Sequential Historical Features (Past-Only)

# %% [markdown]
# ## 4.1 Rolling Historical Mean (Past Only)

# %%
df['rolling_mean_10'] = (
    df.groupby('customer')['amount']
      .transform(lambda x: x.shift(1).rolling(10, min_periods=1).mean())
)

# %% [markdown]
# ## 4.2 Rolling Historical Standard Deviation (Past Only)

# %%
df['rolling_std_10'] = (
    df.groupby('customer')['amount']
      .transform(lambda x: x.shift(1).rolling(10, min_periods=1).std())
)

# %% [markdown]
# ## 4.3 Amount Z-Score Deviation

# %%
df['amount_zscore'] = (
    (df['amount'] - df['rolling_mean_10']) /
    (df['rolling_std_10'] + 1e-6)
)

# %% [markdown]
# # PHASE 5 - Novelty & Behavioral Change Features

# %% [markdown]
# ## 5.1 New Merchant Detection

# %%
df['new_merchant'] = (
    df.groupby('customer')['merchant']
      .transform(lambda x: ~x.duplicated())
      .astype(int)
)

# %% [markdown]
# ## 5.2 Category Novelty

# %%
df['new_category'] = (
    df.groupby('customer')['category']
      .transform(lambda x: ~x.duplicated())
      .astype(int)
)

# %% [markdown]
# # PHASE 6 - Rolling Transaction Burst Detection

# %%
print(df.columns)
# Out:
# Index(['step', 'customer', 'age', 'zipcodeOri', 'merchant', 'zipMerchant',
#        'amount', 'fraud', 'rolling_mean_10', 'rolling_std_10', 'amount_zscore',
#        'new_merchant', 'new_category', 'merchant_freq', 'merchant_repeat',
#        'category_freq', 'category_rare', 'tx_count_10', 'burst_flag',
#        'amount_log', 'high_zscore_flag', 'anomaly_count_20', 'gender_'F'',
#        'gender_'M'', 'gender_'U'', 'category_'es_contents'',
#        'category_'es_fashion'', 'category_'es_food'', 'category_'es_health'',
#        'category_'es_home'', 'category_'es_hotelservices'',
#        'category_'es_hyper'', 'category_'es_leisure'',
#        'category_'es_otherservices'', 'category_'es_sportsandtoys'',
#        'category_'es_tech'', 'category_'es_transportation'',
#        'category_'es_travel'', 'category_'es_wellnessandbeauty''],
#       dtype='object')

# %%
df['merchant_repeat'] = (df['merchant_freq'] > 0).astype(int)

# %%
df['merchant_freq'] = (
    df.groupby(['customer', 'merchant']).cumcount()
)

# %% [markdown]
# # PHASE 7 - Anomaly Flag & Counters

# %% [markdown]
# ## 7.1 Category frequency per customer

# %%
df['category_freq'] = (
    df.groupby(['customer', 'category']).cumcount()
)

# %% [markdown]
# ## 7.2 Category deviation flag

# %%
df['category_rare'] = (df['category_freq'] < 2).astype(int)

# %% [markdown]
# # PHASE 8 - Repetition Tracking

# %%
df['tx_count_10'] = (
    df.groupby('customer')['amount']
      .transform(lambda x: x.shift(1).rolling(10, min_periods=1).count())
)

# %%
df['burst_flag'] = (df['tx_count_10'] > 8).astype(int)

# %% [markdown]
# # PHASE 9 - Log Transformation (Reduce Skewness)

# %% [markdown]
# ## 9.1 High Z-Score Flag

# %%
df['high_zscore_flag'] = (df['amount_zscore'].abs() > 3).astype(int)

# %% [markdown]
# ## 9.2 Rolling anomaly counter

# %%
df['anomaly_count_20'] = (
    df.groupby('customer')['high_zscore_flag']
      .transform(lambda x: x.shift(1).rolling(20, min_periods=1).sum())
)

# %% [markdown]
# # PHASE 10 - Categorical Encoding

# %%
df = pd.get_dummies(df, columns=['gender', 'category'], drop_first=True)

# %% [markdown]
# # PHASE 11 - Feature Scaling

# %%
from sklearn.model_selection import train_test_split

X = df.drop('fraud', axis=1)
y = df['fraud']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=False
)

# %% [markdown]
# # PHASE 12 - Final Cleaning Before Modeling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

num_cols = X_train.select_dtypes(include=np.number).columns

X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])
